# %% [markdown]
# # Tutorial: Analyzing musical pieces on the Tonnetz using *pitchplots*

# %% [markdown]
# ## Overview
#
# ### Introduction
#
# ...
#
# ### The Tonnetz
#
# ...
#
# ### Using *pitchplots*
#
# ...

# %%
from pitchplots.parser import xml_to_csv

# %%
# csv = xml_to_csv("data/frescobaldi_toccata.mxl")
csv = xml_to_csv("data/liszt_benediction.mxl")
# csv = xml_to_csv("data/Liszt_S202_Am_Grabe_R.xml")

# %%
csv.tail(10)
# Out:
#                         filepath      qpm time_sign_num time_sign_den  \
# 9467  data/liszt_benediction.mxl  70.0002             4             4
# 9468  data/liszt_benediction.mxl  70.0002             4             4
# 9469  data/liszt_benediction.mxl  70.0002             4             4
# 9470  data/liszt_benediction.mxl  70.0002             4             4
# 9471  data/liszt_benediction.mxl  70.0002             4             4
# 9472  data/liszt_benediction.mxl  70.0002             4             4
# 9473  data/liszt_benediction.mxl  70.0002             4             4
# 9474  data/liszt_benediction.mxl  70.0002             4             4
# 9475  data/liszt_benediction.mxl  70.0002             4             4
# 9476  data/liszt_benediction.mxl  70.0002             4             4
#
#      measure_no no_accs   mode key_area  type note_name  tpc step  acc octave  \
# 9467        367       6  major  649.767  rest       NaN  NaN  NaN  NaN    NaN
# 9468        367       6  major  649.767  rest       NaN  NaN  NaN  NaN    NaN
# 9469        367       6  major  649.767  note       A#3   A#    A  1.0      3
# 9470        367       6  major  649.767  note       F#4   F#    F  1.0      4
# 9471        367       6  major  649.767  note       C#5   C#    C  1.0      5
# 9472        367       6  major  649.767  note       F#1   F#    F  1.0      1
# 9473        367       6  major  649.767  note       C#2   C#    C  1.0      2
# 9474        367       6  major  649.767  note       F#2   F#    F  1.0      2
# 9475        367       6  major  649.767  rest       NaN  NaN  NaN  NaN    NaN
# 9476        367       6  major  649.767  rest       NaN  NaN  NaN  NaN    NaN
#
#       pitch  pitch_class  duration onset onset_seconds
# 9467    NaN          NaN      0.25   366          1263
# 9468    NaN          NaN      0.25   366          1263
# 9469   58.0         10.0      1.00   366          1263
# 9470   66.0          6.0      1.00   366          1263
# 9471   73.0          1.0      1.00   366          1263
# 9472   30.0          6.0      1.00   366          1263
# 9473   37.0          1.0      1.00   366          1263
# 9474   42.0          6.0      1.00   366          1263
# 9475    NaN          NaN      0.25   366          1263
# 9476    NaN          NaN      0.25   366          1263

# %%
def replace_x(tpc):
    if type(tpc) != float:
        return tpc.replace("x", "##")
    else:
        return tpc

# %%
csv["tpc"] = csv["tpc"].apply(replace_x)

# %%
csv.tpc.value_counts(dropna=True)
# Out:
# C#     1191
# F#     1150
# D#      826
# A#      817
# B       497
# G#      475
# E#      337
# D       329
# A       285
# E       212
# F       199
# G       197
# Bb      125
# C        91
# Eb       88
# B#       77
# F##      60
# Ab       41
# C##      37
# Db       21
# G##      17
# Gb       13
# Cb        4
# D##       3
# Fb        2
# Name: tpc, dtype: int64

# %%
csv.tpc.value_counts().plot(kind="bar")

# %%
from pitchplots.static import tonnetz

# %%
fig = tonnetz(csv, cmap="Reds", colorbar=False, figsize=(8,8), edgecolor="k", radius=4, log=False, fontsize=1.5, show=True, nan_color="w", center="F#")
fig.savefig("benediction.pdf")

# %%
# tonnetz(csv, measures=[9,45])

# %%
tonnetz(csv, measures=[46,55], duration=False, log=False, figsize=(10,10), colorbar=False, nan_color="k", duplicate=False, radius=2)
